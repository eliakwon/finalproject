# %%
import pandas as pd

# %%
df = pd.read_csv("housing_ny.csv")

# %%
df.head(5)
# Out:
#            id                                                url       region  \
# 0  7039954484  https://buffalo.craigslist.org/apa/d/buffalo-h...      buffalo
# 1  7035781383  https://buffalo.craigslist.org/apa/d/buffalo-h...      buffalo
# 2  7030820189  https://ithaca.craigslist.org/apa/d/ithaca-the...       ithaca
# 3  7041794309  https://buffalo.craigslist.org/apa/d/athol-spr...      buffalo
# 4  7032405778  https://longisland.craigslist.org/apa/d/selden...  long island
#
#                           region_url  price       type  sqfeet  beds  baths  \
# 0     https://buffalo.craigslist.org   1280       loft    1078     2    2.0
# 1     https://buffalo.craigslist.org   1280       loft    1078     2    2.0
# 2      https://ithaca.craigslist.org   1270  apartment     850     2    1.0
# 3     https://buffalo.craigslist.org   1375      house    1800     3    1.5
# 4  https://longisland.craigslist.org   2600      house    1000     3    1.0
#
# ...

# %%
df["region"].value_counts()
# Out:
# rochester                  1928
# buffalo                    1379
# albany                     1244
# syracuse                    918
# new york city               763
# hudson valley               710
# ithaca                      641
# long island                 570
# watertown                   410
# binghamton                  289
# glens falls                 215
# potsdam-canton-massena      191
# finger lakes                172
# utica-rome-oneida           154
# elmira-corning              153
# oneonta                      77
# plattsburgh-adirondacks      65
# catskills                    51
# chautauqua                   43
# twin tiers NY/PA             18
# Name: region, dtype: int64

# %%
#Max price 
df.loc[df["price"].idxmax()]
# Out:
# id                                                                7047477916
# url                        https://hudsonvalley.craigslist.org/apa/d/pelh...
# region                                                         hudson valley
# region_url                               https://hudsonvalley.craigslist.org
# price                                                               18502000
# type                                                               apartment
# sqfeet                                                                   900
# beds                                                                       2
# baths                                                                      1
# cats_allowed                                                               1
# dogs_allowed                                                               0
# smoking_allowed                                                            1
# ...

# %%
#Min Price 
df.loc[df["price"].idxmin()]
# Out:
# id                                                                7050777666
# url                        https://albany.craigslist.org/apa/d/albany-thi...
# region                                                                albany
# region_url                                     https://albany.craigslist.org
# price                                                                      0
# type                                                                   house
# sqfeet                                                                  1428
# beds                                                                       4
# baths                                                                    1.5
# cats_allowed                                                               1
# dogs_allowed                                                               1
# smoking_allowed                                                            1
# ...

# %%
# Apt count per number of bedrooms
df["beds"].value_counts()
# Out:
# 2    4647
# 1    2401
# 3    1938
# 4     465
# 0     396
# 5      96
# 6      36
# 7       7
# 8       5
# Name: beds, dtype: int64

# %%
df["region"].value_counts()
# Out:
# rochester                  1928
# buffalo                    1379
# albany                     1244
# syracuse                    918
# new york city               763
# hudson valley               710
# ithaca                      641
# long island                 570
# watertown                   410
# binghamton                  289
# glens falls                 215
# potsdam-canton-massena      191
# finger lakes                172
# utica-rome-oneida           154
# elmira-corning              153
# oneonta                      77
# plattsburgh-adirondacks      65
# catskills                    51
# chautauqua                   43
# twin tiers NY/PA             18
# Name: region, dtype: int64

# %%
df["type"].value_counts()
# Out:
# apartment        7691
# house            1126
# townhouse         653
# duplex            198
# manufactured      126
# condo              87
# loft               56
# cottage/cabin      36
# flat               12
# in-law              6
# Name: type, dtype: int64

# %%
df[df['type'] == 'loft']
# Out:
#               id                                                url  \
# 0     7039954484  https://buffalo.craigslist.org/apa/d/buffalo-h...
# 1     7035781383  https://buffalo.craigslist.org/apa/d/buffalo-h...
# 1178  7038530036  https://albany.craigslist.org/apa/d/albany-ope...
# 1345  7037031763  https://albany.craigslist.org/apa/d/albany-lux...
# 2242  7043344726  https://buffalo.craigslist.org/apa/d/buffalo-h...
# 2246  7041263587  https://buffalo.craigslist.org/apa/d/buffalo-h...
# 2247  7041263286  https://buffalo.craigslist.org/apa/d/buffalo-h...
# 2248  7039954696  https://buffalo.craigslist.org/apa/d/buffalo-h...
# 2249  7041263075  https://buffalo.craigslist.org/apa/d/buffalo-h...
# 2250  7039954540  https://buffalo.craigslist.org/apa/d/buffalo-h...
# 2251  7039954598  https://buffalo.craigslist.org/apa/d/buffalo-h...
# 2252  7039954744  https://buffalo.craigslist.org/apa/d/buffalo-h...
# 2253  7035988211  https://buffalo.craigslist.org/apa/d/buffalo-h...
# ...

# %%
mask = df['type'] == 'house'

# %%
df[mask]
# Out:
#               id                                                url  \
# 3     7041794309  https://buffalo.craigslist.org/apa/d/athol-spr...
# 4     7032405778  https://longisland.craigslist.org/apa/d/selden...
# 6     7037628861  https://ithaca.craigslist.org/apa/d/ithaca-2-b...
# 10    7047084152  https://buffalo.craigslist.org/apa/d/buffalo-f...
# 11    7047082711  https://buffalo.craigslist.org/apa/d/buffalo-r...
# ...          ...                                                ...
# 9947  7016419126  https://watertown.craigslist.org/apa/d/1-month...
# 9965  7027557146  https://watertown.craigslist.org/apa/d/waterto...
# 9966  7025073943  https://watertown.craigslist.org/apa/d/dexter-...
# 9976  7027052069  https://watertown.craigslist.org/apa/d/amazing...
# 9984  7011687650  https://watertown.craigslist.org/apa/d/1-month...
#
#            region                         region_url  price   type  sqfeet  \
# ...

# %%
#property less than $2,000
df[df['price']< 2000]
# Out:
#               id                                                url  \
# 0     7039954484  https://buffalo.craigslist.org/apa/d/buffalo-h...
# 1     7035781383  https://buffalo.craigslist.org/apa/d/buffalo-h...
# 2     7030820189  https://ithaca.craigslist.org/apa/d/ithaca-the...
# 3     7041794309  https://buffalo.craigslist.org/apa/d/athol-spr...
# 5     7049729805  https://hudsonvalley.craigslist.org/apa/d/midd...
# ...          ...                                                ...
# 9986  7006696603  https://watertown.craigslist.org/apa/d/sackets...
# 9987  7006703572  https://watertown.craigslist.org/apa/d/waterto...
# 9988  7006719502  https://watertown.craigslist.org/apa/d/waterto...
# 9989  7006708023  https://watertown.craigslist.org/apa/d/pcsing-...
# 9990  7025168396  https://watertown.craigslist.org/apa/d/calcium...
#
#              region                           region_url  price       type  \
# ...

# %%
df[df["price"].between(2500, 3500)]
# Out:
#               id                                                url  \
# 4     7032405778  https://longisland.craigslist.org/apa/d/selden...
# 8     7050920951  https://plattsburgh.craigslist.org/apa/d/platt...
# 17    7039901070  https://catskills.craigslist.org/apa/d/montice...
# 54    7040114221  https://plattsburgh.craigslist.org/apa/d/platt...
# 79    7039962249  https://longisland.craigslist.org/apa/d/glen-h...
# ...          ...                                                ...
# 8720  7046273866  https://syracuse.craigslist.org/apa/d/cazenovi...
# 8731  7040195856  https://syracuse.craigslist.org/apa/d/syracuse...
# 9050  7024410314  https://syracuse.craigslist.org/apa/d/syracuse...
# 9241  7019808877  https://syracuse.craigslist.org/apa/d/fayettev...
# 9283  7016228375  https://syracuse.craigslist.org/apa/d/fayettev...
#
#                        region                          region_url  price  \
# 4                 long island   https://longisland.craigslist.org   2600
# ...

# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

# %%
df = pd.read_csv("housing_ny.csv")

# %%
house_price = df[df['type'] == 'house']['price']
house_bedroom = df[df['type'] == 'house']['beds']

condo_price = df[df['type'] == 'condo']['price']
condo_bedroom = df[df['type'] == 'condo']['beds']

# %%
house_bedroom
# Out:
# 3       3
# 4       3
# 6       2
# 10      2
# 11      2
#        ..
# 9947    3
# 9965    2
# 9966    1
# 9976    2
# 9984    3
# Name: beds, Length: 1126, dtype: int64

# %%
plt.plot(condo_bedroom, condo_price, label = "Condo")
plt.xlabel("Beds")
plt.ylabel("Price (USD)")
plt.title("Average Price (USD) by Beds for Condo")
plt.show()

# %%
plt.plot(condo_bedroom, condo_price, label = "Condo", color='#54BECA', marker='.', linestyle='--')
plt.plot(house_bedroom, house_price, label = "House", color='#9C257C', marker='o')
plt.xlabel("Beds")
plt.ylabel("Price (USD)")
plt.title("Average Price (USD) by Beds for Condo/House")
plt.legend()
plt.grid(True)
plt.show()
